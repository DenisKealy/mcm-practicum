# %% [markdown]
# # Coocurrence Network for Perceptual Scent Data
#
#
# From a research article titled: *"Understanding the Odour Spaces: A Step towards Solving Olfactory Stimulus-Percept Problem"*, published in the plos one journal in 2015: doi.org/10.1371/journal.pone.0141263
#
# *"We can describe each database as an undirected graph or network, where nodes are perceptual descriptors and an edge is shared by two perceptual descriptors if they have occurred together in the perceptual description of a molecule."*
#
# *"**The important questions to be addressed with respect to the perceptual network are about its structural organisation, particularly, its difference from a random network and its degree distribution**. We also sought to understand whether the positioning of the perceptual descriptors is only due to their semantic relatedness."*
#
# So for each dataset I aim to calculate the same network characteristics that these researchers used in their analysis and replicate their work on both their data, as well as newly released data. In the supplementary materials of their publication they included detailed methods of how they calculated the network statistics and how they compared it against random networks.
#
# The aim of this exercise is to understand the quality of our data, and understand how the characteristics differ between data sources. Finally I would like to understand my results by comparing our networks to the networks constructed and analysed in 2015.
#
#
# ## Data Sources analysed by Kumar Et al. 2015
#
#
#
# <img src="database_descriptions.png">
#
#
#
#
# ## Network Characteristics from Kumar Et al. 2015
#
# We are not going to calculate every column below - just the ones nessecary to compute the clustering coefficient and compare our networks with some randomly generated networks. From the paper:
#
# *"The clustering coefficient can be used to differentiate the properties of the nodes from a random network. We have calculated the weighted clustering coefficient proposed by Barrat et al.[7]."*
#
#
#
# <img src="network_descriptions.png">
#
#
# ### Columns
#
# - Nodes (one for each percept that occurs at least once with another percept e.g. fish)
# - Edges (one for each coocurrence between smells - multiple coocurrences are common and are accounted for by the weight of the edges)
# - Average degree (A) is defined as two times the number of edges divided by the number of nodes
# - Network diameter N(d) is the longest direct path between any two nodes in the network
# - Average Path Length N(l)
# - Graph Density D(g)
# - α = Power law exponent
# - X(min) = Power law cutoff degree
# - r = Assortativity Coefficient
# - **cl(avg) = Network Average Clustering Coefficient:** We will calculate this coefficient for each dataset.
# - **R-cl(avg) = Random Clustering Coefficient:** We will calculate an average clustering coefficient from our random netowrks of equal nodes and edges to the corresponding perceptual network.
#
# ## Replicating Results and Verifying our Data Collection
#
# The goal of this notebook is to calculate and compare the final two statistics in the image above for our data, namely: the global/average clustering coefficient and a corresponding average random clustering coefficient. We generate 1000 random graphs using the Erdős–Rényi G(n, M) model - where n is the number of nodes and M is the number of edges. The random graphs have an equal number of edges/nodes as the smell coocurrence graph that they are to be compared with.
#
# We use a z-test to test whether the real network could have came from the distribution of 1000 random graphs (which should have a normally distributed average clustering coefficient due to the Central Limit Theorem).

# %% [markdown]
# # Flavornet
#
# This data was scraped from a live online database on 14th November 2017. The databse is available here: http://www.flavornet.org/flavornet.html

# %%
import json
import numpy as np
import pandas as pd

df = pd.read_json('/Users/admin/workspace/2018-mcm-kealyd2/data/flavornet.json') 

percepts = set()

# %%
for row in df.iterrows():
    u = row[1][2]
    string = u.encode('ascii','ignore')
    if ',' in string:
        strings = string.split(', ')
        for percept in strings:
            percepts.add(percept)
    else:
        percepts.add(string)
        
print(percepts)
# Out:
# set(['turpentine', 'urine', 'thyme', 'green tea', 'fecal', 'fennel', 'paper', 'seaweed', 'earth', 'bitter almond', 'rubber', 'grape', 'rose', 'walnut', 'celery', 'roast beef', 'geranium', 'wood', 'orange', 'sulfur', 'spice', 'green leaf', 'coffee', 'yeast', 'citrus', 'fat', 'mandarin', 'watermelon', 'nutmeg', 'burnt', 'roasted meat', 'bread', 'coriander', 'cooked potato', 'lactone', 'meat', 'onion', 'resin', 'green pepper', 'caramel', 'roast', 'tallow', 'vanilla', 'brown sugar', 'wintergreen', 'lilac', 'cooked meat', 'gasoline', 'fish', 'almond', 'lavender', 'cologne', 'burnt sugar', 'oil', 'violet', 'mildew', 'acid', 'butterscotch', 'putrid', 'flower', 'leaf', 'alcohol', 'whiskey', 'menthol', 'horseradish', 'herb', 'medicine', 'truffle', 'hot milk', 'boiled vegetable', 'pea', 'pepper', 'solvent', 'alkane', 'alkaline', 'jasmine', 'camomile', 'vinyl', 'raspberry', 'cooked vegetable', 'fried', 'apple peel', 'biscuit', 'hummus', 'roasted nut', 'sweat', 'smoke', 'muguet', 'popcorn', 'wet cloth', 'curry', 'peanut butter', 'cheese', 'apple', 'marshmallow', 'straw', 'sweet', 'cotton candy', 'cocoa', 'lettuce', 'amine', 'soy', 'crushed bug', 'ether', 'maple', 'cardboard', 'balsamic', 'anise', 'licorice', 'plastic', 'coumarin', 'paint', 'green bean', 'beet', 'wax', 'basil', 'mothball', 'bitter', 'banana', 'hyacinth', 'butter', 'mushroom', 'pesticide', 'tomato leaf', 'melon', 'warm', 'nut', 'hazelnut', 'weak spice', 'spearmint', 'must', 'tobacco', 'box tree', 'apricot', 'malt', 'almond shell', 'pungent', 'peppermint', 'cat', 'strawberry', 'sour', 'grass', 'plum', 'prune', 'tart lime', 'dill', 'coconut', 'tar', 'cucumber', 'honey', 'carrot', 'tea', 'sharp', 'mint', 'cream', 'meat broth', 'clove', 'lemon', 'terpentine', 'peach', 'mold', 'thiamin', 'pine', 'chemical', 'phenol', 'foxy', 'ester', 'orris', 'lily', 'soap', 'cinnamon', 'black currant', 'mustard', 'pear', 'hawthorne', 'orange peel', 'fruit', 'garlic', 'moss', 'dust', 'cabbage', 'grapefruit', 'broccoli', 'tomato', 'caraway', 'potato', 'cognac', 'metal', 'rancid', 'green', 'camphor', 'pineapple', 'fresh', 'baked', 'magnolia', 'wine'])

# %%
bipartite = pd.DataFrame(None, None, percepts)

# %%
print(bipartite.columns)
# Out:
# Index([u'turpentine', u'urine', u'thyme', u'green tea', u'fecal', u'fennel',
#        u'paper', u'seaweed', u'earth', u'bitter almond',
#        ...
#        u'cognac', u'metal', u'rancid', u'green', u'camphor', u'pineapple',
#        u'fresh', u'baked', u'magnolia', u'wine'],
#       dtype='object', length=196)

# %%
rows = pd.DataFrame([[0 for col in range(196)]], df['CAS_no'])
rows.columns = bipartite.columns
bipartite = rows

# %%
for row in df.iterrows():
    u = row[1][2]
    cas = row[1][0]
    string = u.encode('ascii','ignore')
    
    if ',' in string:
        strings = string.split(', ')
        for percept in strings:
            bipartite[percept][cas] = 1
                    
    else:
        bipartite[string][cas] = 1

# %%
print(bipartite)
# Out:
#             turpentine  urine  thyme  green tea  fecal  fennel  paper  \
# CAS_no
# 75-50-3              0      0      0          0      0       0      0
# 75-07-0              0      0      0          0      0       0      0
# 74-93-1              0      0      0          0      0       0      0
# 123-38-6             0      0      0          0      0       0      0
# 109-66-0             0      0      0          0      0       0      0
# 71-23-8              0      0      0          0      0       0      0
# 75-18-3              0      0      0          0      0       0      0
# 109-94-4             0      0      0          0      0       0      0
# 78-93-3              0      0      0          0      0       0      0
# 624-89-5             0      0      0          0      0       0      0
# 110-54-3             0      0      0          0      0       0      0
# 141-78-6             0      0      0          0      0       0      0
# 115-18-4             0      0      0          0      0       0      0
# 96-22-0              0      0      0          0      0       0      0
# 78-83-1              0      0      0          0      0       0      0
# 123-73-9             0      0      0          0      0       0      0
# 565-69-5             0      0      0          0      0       0      0
# 96-17-3              0      0      0          0      0       0      0
# 590-86-3             0      0      0          0      0       0      0
# 123-75-1             0      0      0          0      0       0      0
# 64-17-5              0      0      0          0      0       0      0
# 110-02-1             0      0      0          0      0       0      0
# 79-09-4              0      0      0          0      0       0      0
# 431-03-8             0      0      0          0      0       0      0
# 556-24-1             0      0      0          0      0       0      0
# 71-36-3              0      0      0          0      0       0      0
# 78-92-2              0      0      0          0      0       0      0
# 4124-63-4            0      0      0          0      0       0      0
# 123-72-8             0      0      0          0      0       0      0
# 1629-58-9            0      0      0          0      0       0      0
# ...                ...    ...    ...        ...    ...     ...    ...
# 628-97-7             0      0      0          0      0       0      0
# 97-54-1              0      0      0          0      0       0      0
# 629-92-5             0      0      0          0      0       0      0
# 104-67-6             0      0      0          0      0       0      0
# 4128-17-0            0      0      0          0      0       0      0
# 81018-77-1           0      0      0          0      0       0      0
# 91-10-1              0      0      0          0      0       0      0
# 142-91-6             0      0      0          0      0       0      0
# 87-91-2              0      0      0          0      0       0      0
# 1117-52-8            0      0      0          0      0       0      0
# 112-95-8             0      0      0          0      0       0      0
# 5932-68-3            0      0      0          0      0       0      0
# 638-66-4             0      0      0          0      0       0      0
# 2628-17-3            0      0      0          0      0       0      0
# 112-80-1             0      0      0          0      0       0      0
# 112-61-8             0      0      0          0      0       0      0
# 95908-33-1           0      0      0          0      0       0      0
# 112-72-1             0      0      0          0      0       0      0
# 629-94-7             0      0      0          0      0       0      0
# 150-86-7             0      0      0          0      0       0      0
# 67-47-0              0      0      0          0      0       0      0
# 143-07-7             0      0      0          0      0       0      0
# 629-97-0             0      0      0          0      0       0      0
# 6627-88-9            0      0      0          0      0       0      0
# 112-92-5             0      0      0          0      0       0      0
# 3943-74-6            0      0      0          0      0       0      0
# 617-05-0             0      0      0          0      0       0      0
# 498-02-2             0      0      0          0      0       0      0
# 34318-21-3           0      0      0          0      0       0      0
# 638-67-5             0      0      0          0      0       0      0
#
#             seaweed  earth  bitter almond  ...   cognac  metal  rancid  green  \
# CAS_no                                     ...
# 75-50-3           0      0              0  ...        0      0       0      0
# 75-07-0           0      0              0  ...        0      0       0      0
# 74-93-1           0      0              0  ...        0      0       0      0
# 123-38-6          0      0              0  ...        0      0       0      0
# 109-66-0          0      0              0  ...        0      0       0      0
# 71-23-8           0      0              0  ...        0      0       0      0
# 75-18-3           0      0              0  ...        0      0       0      0
# 109-94-4          0      0              0  ...        0      0       0      0
# 78-93-3           0      0              0  ...        0      0       0      0
# 624-89-5          0      0              0  ...        0      0       0      0
# 110-54-3          0      0              0  ...        0      0       0      0
# 141-78-6          0      0              0  ...        0      0       0      0
# 115-18-4          0      0              0  ...        0      0       0      0
# 96-22-0           0      0              0  ...        0      0       0      0
# 78-83-1           0      0              0  ...        0      0       0      0
# 123-73-9          0      0              0  ...        0      0       0      0
# 565-69-5          0      0              0  ...        0      0       0      0
# 96-17-3           0      0              0  ...        0      0       0      0
# 590-86-3          0      0              0  ...        0      0       0      0
# 123-75-1          0      0              0  ...        0      0       0      0
# 64-17-5           0      0              0  ...        0      0       0      0
# 110-02-1          0      0              0  ...        0      0       0      0
# 79-09-4           0      0              0  ...        0      0       1      0
# 431-03-8          0      0              0  ...        0      0       0      0
# 556-24-1          0      0              0  ...        0      0       0      0
# 71-36-3           0      0              0  ...        0      0       0      0
# 78-92-2           0      0              0  ...        0      0       0      0
# 4124-63-4         0      0              0  ...        0      0       0      0
# 123-72-8          0      0              0  ...        0      0       0      1
# 1629-58-9         0      0              0  ...        0      0       0      0
# ...             ...    ...            ...  ...      ...    ...     ...    ...
# 628-97-7          0      0              0  ...        0      0       0      0
# 97-54-1           0      0              0  ...        0      0       0      0
# 629-92-5          0      0              0  ...        0      0       0      0
# 104-67-6          0      0              0  ...        0      0       0      0
# 4128-17-0         0      0              0  ...        0      0       0      0
# 81018-77-1        0      0              0  ...        0      0       0      1
# 91-10-1           0      0              0  ...        0      0       0      0
# 142-91-6          0      0              0  ...        0      0       0      0
# 87-91-2           0      1              0  ...        0      0       0      0
# 1117-52-8         0      0              0  ...        0      0       0      0
# 112-95-8          0      0              0  ...        0      0       0      0
# 5932-68-3         0      0              0  ...        0      0       0      0
# 638-66-4          0      0              0  ...        0      0       0      0
# 2628-17-3         0      0              0  ...        0      0       0      0
# 112-80-1          0      0              0  ...        0      0       0      0
# 112-61-8          0      0              0  ...        0      0       0      0
# 95908-33-1        0      0              0  ...        0      0       0      0
# 112-72-1          0      0              0  ...        0      0       0      0
# 629-94-7          0      0              0  ...        0      0       0      0
# 150-86-7          0      0              0  ...        0      0       0      0
# 67-47-0           0      0              0  ...        0      0       0      0
# 143-07-7          0      0              0  ...        0      1       0      0
# 629-97-0          0      0              0  ...        0      0       0      0
# 6627-88-9         0      0              0  ...        0      0       0      0
# 112-92-5          0      0              0  ...        0      0       0      0
# 3943-74-6         0      0              0  ...        0      0       0      0
# 617-05-0          0      0              0  ...        0      0       0      0
# 498-02-2          0      0              0  ...        0      0       0      0
# 34318-21-3        0      0              0  ...        0      0       0      0
# 638-67-5          0      0              0  ...        0      0       0      0
#
#             camphor  pineapple  fresh  baked  magnolia  wine
# CAS_no
# 75-50-3           0          0      0      0         0     0
# 75-07-0           0          0      0      0         0     0
# 74-93-1           0          0      0      0         0     0
# 123-38-6          0          0      0      0         0     0
# 109-66-0          0          0      0      0         0     0
# 71-23-8           0          0      0      0         0     0
# 75-18-3           0          0      0      0         0     0
# 109-94-4          0          0      0      0         0     0
# 78-93-3           0          0      0      0         0     0
# 624-89-5          0          0      0      0         0     0
# 110-54-3          0          0      0      0         0     0
# 141-78-6          0          1      0      0         0     0
# 115-18-4          0          0      0      0         0     0
# 96-22-0           0          0      0      0         0     0
# 78-83-1           0          0      0      0         0     1
# 123-73-9          0          0      0      0         0     0
# 565-69-5          0          0      0      0         0     0
# 96-17-3           0          0      0      0         0     0
# 590-86-3          0          0      0      0         0     0
# 123-75-1          0          0      0      0         0     0
# 64-17-5           0          0      0      0         0     0
# 110-02-1          0          0      0      0         0     0
# 79-09-4           0          0      0      0         0     0
# 431-03-8          0          0      0      0         0     0
# 556-24-1          0          0      0      0         0     0
# 71-36-3           0          0      0      0         0     0
# 78-92-2           0          0      0      0         0     1
# 4124-63-4         0          0      0      0         0     0
# 123-72-8          0          0      0      0         0     0
# 1629-58-9         0          0      0      0         0     0
# ...             ...        ...    ...    ...       ...   ...
# 628-97-7          0          0      0      0         0     0
# 97-54-1           0          0      0      0         0     0
# 629-92-5          0          0      0      0         0     0
# 104-67-6          0          0      0      0         0     0
# 4128-17-0         0          0      0      0         0     0
# 81018-77-1        0          0      0      0         0     0
# 91-10-1           0          0      0      0         0     0
# 142-91-6          0          0      0      0         0     0
# 87-91-2           0          0      0      0         0     0
# 1117-52-8         0          0      0      0         0     0
# 112-95-8          0          0      0      0         0     0
# 5932-68-3         0          0      0      0         0     0
# 638-66-4          0          0      0      0         0     0
# 2628-17-3         0          0      0      0         0     0
# 112-80-1          0          0      0      0         0     0
# 112-61-8          0          0      0      0         0     0
# 95908-33-1        0          0      0      0         0     0
# 112-72-1          0          0      0      0         0     0
# 629-94-7          0          0      0      0         0     0
# 150-86-7          0          0      0      0         0     0
# 67-47-0           0          0      0      0         0     0
# 143-07-7          0          0      0      0         0     0
# 629-97-0          0          0      0      0         0     0
# 6627-88-9         0          0      0      0         0     0
# 112-92-5          0          0      0      0         0     0
# 3943-74-6         0          0      0      0         0     0
# 617-05-0          0          0      0      0         0     0
# 498-02-2          0          0      0      0         0     0
# 34318-21-3        0          0      0      0         0     0
# 638-67-5          0          0      0      0         0     0
#
# [738 rows x 196 columns]

# %%
cooc = bipartite.transpose().dot(bipartite) # - create co-occurence matrix
cooc
# Out:
#                turpentine  urine  thyme  green tea  fecal  fennel  paper  \
# turpentine             12      0      0          0      0       0      0
# urine                   0      1      0          0      0       0      0
# thyme                   0      0      1          0      0       0      0
# green tea               0      0      0          1      0       0      0
# fecal                   0      0      0          0      2       0      0
# fennel                  0      0      0          0      0       1      0
# paper                   0      0      0          0      0       0      1
# seaweed                 0      0      0          0      0       0      0
# earth                   0      0      0          0      0       0      0
# bitter almond           0      0      0          0      0       0      0
# rubber                  0      0      0          0      0       0      0
# grape                   0      0      0          0      0       0      0
# rose                    0      0      0          0      0       0      0
# walnut                  0      0      0          0      0       0      0
# celery                  0      0      0          0      0       0      0
# roast beef              0      0      0          0      0       0      0
# geranium                0      0      0          0      0       0      0
# wood                    1      0      1          0      0       0      0
# orange                  0      0      0          0      0       0      0
# sulfur                  0      0      0          0      0       0      0
# spice                   1      0      0          1      0       0      0
# green leaf              0      0      0          0      0       0      0
# coffee                  0      0      0          0      0       0      0
# yeast                   0      0      0          0      0       0      0
# citrus                  0      0      0          0      0       0      0
# fat                     0      0      0          0      0       0      0
# mandarin                0      0      0          0      0       0      0
# watermelon              0      0      0          0      0       0      0
# nutmeg                  1      0      0          0      0       0      0
# burnt                   0      0      0          0      0       0      0
# ...                   ...    ...    ...        ...    ...     ...    ...
# ester                   0      0      0          0      0       0      0
# orris                   0      0      0          0      0       0      0
# lily                    0      0      0          0      0       0      0
# soap                    0      0      0          0      0       0      0
# cinnamon                0      0      0          0      0       0      0
# black currant           0      0      0          0      0       0      0
# mustard                 0      0      0          0      0       0      0
# pear                    0      0      0          0      0       0      0
# hawthorne               0      0      0          0      0       0      0
# orange peel             0      0      0          0      0       0      0
# fruit                   1      0      0          0      0       0      0
# garlic                  0      0      0          0      0       0      0
# moss                    0      0      0          0      0       0      0
# dust                    0      0      0          0      0       0      0
# cabbage                 0      0      0          0      0       0      0
# grapefruit              0      0      0          0      0       0      0
# broccoli                0      0      0          0      0       0      0
# tomato                  0      0      0          0      0       0      0
# caraway                 0      0      0          0      0       0      0
# potato                  0      0      0          0      0       0      0
# cognac                  0      0      0          0      0       0      0
# metal                   0      0      0          0      0       0      0
# rancid                  0      0      0          0      0       0      0
# green                   0      0      0          0      0       0      0
# camphor                 0      0      0          0      0       0      0
# pineapple               0      0      0          0      0       0      0
# fresh                   0      0      0          0      0       0      0
# baked                   0      0      0          0      0       0      0
# magnolia                0      0      0          0      0       0      0
# wine                    0      0      0          0      0       0      0
#
#                seaweed  earth  bitter almond  ...   cognac  metal  rancid  \
# turpentine           0      0              0  ...        0      0       0
# urine                0      0              0  ...        0      0       0
# thyme                0      0              0  ...        0      0       0
# green tea            0      0              0  ...        0      0       0
# fecal                0      0              0  ...        0      0       0
# fennel               0      0              0  ...        0      0       0
# paper                0      0              0  ...        0      0       0
# seaweed              3      0              0  ...        0      0       0
# earth                0     22              0  ...        0      0       0
# bitter almond        0      0              1  ...        0      0       0
# rubber               0      0              0  ...        0      0       0
# grape                0      0              0  ...        0      0       0
# rose                 0      0              0  ...        0      0       0
# walnut               0      0              0  ...        0      0       0
# celery               0      0              0  ...        0      0       0
# roast beef           0      0              0  ...        0      0       0
# geranium             0      0              0  ...        0      1       0
# wood                 0      1              0  ...        0      0       0
# orange               0      0              0  ...        0      0       0
# sulfur               0      0              0  ...        0      0       0
# spice                0      3              0  ...        0      0       0
# green leaf           0      0              0  ...        0      0       0
# coffee               0      0              0  ...        0      0       0
# yeast                0      0              0  ...        0      0       0
# citrus               0      1              0  ...        0      0       1
# fat                  0      0              0  ...        0      0       3
# mandarin             0      0              0  ...        0      0       0
# watermelon           0      0              0  ...        0      0       0
# nutmeg               0      0              0  ...        0      0       0
# burnt                0      0              0  ...        0      1       0
# ...                ...    ...            ...  ...      ...    ...     ...
# ester                0      0              0  ...        0      0       0
# orris                0      0              0  ...        0      0       0
# lily                 0      0              0  ...        0      0       0
# soap                 0      0              0  ...        0      0       0
# cinnamon             0      0              0  ...        0      0       0
# black currant        0      0              0  ...        0      0       0
# mustard              0      0              0  ...        0      0       0
# pear                 0      0              0  ...        0      0       0
# hawthorne            0      0              0  ...        0      0       0
# orange peel          0      0              0  ...        0      0       0
# fruit                0      0              0  ...        0      0       0
# garlic               0      0              0  ...        0      0       0
# moss                 0      2              0  ...        0      0       0
# dust                 0      0              0  ...        0      0       0
# cabbage              0      0              0  ...        0      0       0
# grapefruit           0      0              0  ...        0      0       0
# broccoli             0      0              0  ...        0      0       0
# tomato               0      0              0  ...        0      0       0
# caraway              0      0              0  ...        0      0       0
# potato               0      0              0  ...        0      0       0
# cognac               0      0              0  ...        1      0       0
# metal                0      0              0  ...        0     13       0
# rancid               0      0              0  ...        0      0      10
# green                1      3              0  ...        0      1       0
# camphor              0      1              0  ...        0      0       0
# pineapple            0      0              0  ...        0      0       0
# fresh                0      0              0  ...        0      0       0
# baked                0      0              0  ...        0      0       0
# magnolia             0      0              0  ...        0      0       0
# wine                 0      0              0  ...        0      0       0
#
#                green  camphor  pineapple  fresh  baked  magnolia  wine
# turpentine         0        0          0      0      0         0     0
# urine              0        0          0      0      0         0     0
# thyme              0        0          0      0      0         0     0
# green tea          0        0          0      0      0         0     0
# fecal              0        0          0      0      0         0     0
# fennel             0        0          0      0      0         0     0
# paper              0        0          0      0      0         0     0
# seaweed            1        0          0      0      0         0     0
# earth              3        1          0      0      0         0     0
# bitter almond      0        0          0      0      0         0     0
# rubber             1        0          0      0      0         0     0
# grape              0        0          0      0      0         0     0
# rose               1        0          0      0      0         0     0
# walnut             1        0          0      0      0         0     0
# celery             0        0          0      0      0         0     0
# roast beef         0        0          0      0      0         0     0
# geranium           0        0          0      0      0         0     0
# wood               5        1          0      0      0         0     0
# orange             1        0          0      1      0         0     0
# sulfur             1        0          0      0      0         0     0
# spice              0        0          0      1      0         0     0
# green leaf         0        0          0      0      0         0     0
# coffee             0        0          0      0      0         0     0
# yeast              0        0          0      0      0         0     0
# citrus             4        1          0      2      0         0     0
# fat                9        0          0      0      0         0     0
# mandarin           0        0          0      0      0         0     0
# watermelon         0        0          0      0      0         0     0
# nutmeg             0        0          0      0      0         0     0
# burnt              0        0          0      0      0         0     0
# ...              ...      ...        ...    ...    ...       ...   ...
# ester              0        0          0      0      0         0     0
# orris              0        0          0      0      0         0     0
# lily               0        0          0      0      0         0     0
# soap               3        0          0      0      0         0     0
# cinnamon           0        0          0      0      0         0     0
# black currant      0        0          0      0      0         0     0
# mustard            0        0          0      0      0         0     0
# pear               0        0          0      0      0         0     0
# hawthorne          0        0          0      0      0         0     0
# orange peel        0        0          0      0      0         0     0
# fruit              4        0          0      1      0         0     2
# garlic             0        0          0      0      0         0     0
# moss               0        0          0      1      0         0     0
# dust               0        0          0      0      0         0     0
# cabbage            0        0          0      0      0         0     0
# grapefruit         0        0          0      0      0         0     0
# broccoli           0        0          0      0      0         0     0
# tomato             0        0          0      0      0         0     0
# caraway            0        0          0      1      0         0     0
# potato             0        0          0      0      0         0     0
# cognac             0        0          0      0      0         0     0
# metal              1        0          0      0      0         0     0
# rancid             0        0          0      0      0         0     0
# green             66        1          0      2      0         1     2
# camphor            1       12          0      0      0         0     0
# pineapple          0        0          3      0      0         0     0
# fresh              2        0          0     15      0         0     0
# baked              0        0          0      0      2         0     0
# magnolia           1        0          0      0      0         1     0
# wine               2        0          0      0      0         0     7
#
# [196 rows x 196 columns]

# %%
# Make a copy of the cooc matrix
cooc_zero_diagonal = cooc.copy()
# Remove diagonal entries - these correspond to the total frequency of each word
np.fill_diagonal(cooc_zero_diagonal.values, 0)
cooc_zero_diagonal
# Out:
#                turpentine  urine  thyme  green tea  fecal  fennel  paper  \
# turpentine              0      0      0          0      0       0      0
# urine                   0      0      0          0      0       0      0
# thyme                   0      0      0          0      0       0      0
# green tea               0      0      0          0      0       0      0
# fecal                   0      0      0          0      0       0      0
# fennel                  0      0      0          0      0       0      0
# paper                   0      0      0          0      0       0      0
# seaweed                 0      0      0          0      0       0      0
# earth                   0      0      0          0      0       0      0
# bitter almond           0      0      0          0      0       0      0
# rubber                  0      0      0          0      0       0      0
# grape                   0      0      0          0      0       0      0
# rose                    0      0      0          0      0       0      0
# walnut                  0      0      0          0      0       0      0
# celery                  0      0      0          0      0       0      0
# roast beef              0      0      0          0      0       0      0
# geranium                0      0      0          0      0       0      0
# wood                    1      0      1          0      0       0      0
# orange                  0      0      0          0      0       0      0
# sulfur                  0      0      0          0      0       0      0
# spice                   1      0      0          1      0       0      0
# green leaf              0      0      0          0      0       0      0
# coffee                  0      0      0          0      0       0      0
# yeast                   0      0      0          0      0       0      0
# citrus                  0      0      0          0      0       0      0
# fat                     0      0      0          0      0       0      0
# mandarin                0      0      0          0      0       0      0
# watermelon              0      0      0          0      0       0      0
# nutmeg                  1      0      0          0      0       0      0
# burnt                   0      0      0          0      0       0      0
# ...                   ...    ...    ...        ...    ...     ...    ...
# ester                   0      0      0          0      0       0      0
# orris                   0      0      0          0      0       0      0
# lily                    0      0      0          0      0       0      0
# soap                    0      0      0          0      0       0      0
# cinnamon                0      0      0          0      0       0      0
# black currant           0      0      0          0      0       0      0
# mustard                 0      0      0          0      0       0      0
# pear                    0      0      0          0      0       0      0
# hawthorne               0      0      0          0      0       0      0
# orange peel             0      0      0          0      0       0      0
# fruit                   1      0      0          0      0       0      0
# garlic                  0      0      0          0      0       0      0
# moss                    0      0      0          0      0       0      0
# dust                    0      0      0          0      0       0      0
# cabbage                 0      0      0          0      0       0      0
# grapefruit              0      0      0          0      0       0      0
# broccoli                0      0      0          0      0       0      0
# tomato                  0      0      0          0      0       0      0
# caraway                 0      0      0          0      0       0      0
# potato                  0      0      0          0      0       0      0
# cognac                  0      0      0          0      0       0      0
# metal                   0      0      0          0      0       0      0
# rancid                  0      0      0          0      0       0      0
# green                   0      0      0          0      0       0      0
# camphor                 0      0      0          0      0       0      0
# pineapple               0      0      0          0      0       0      0
# fresh                   0      0      0          0      0       0      0
# baked                   0      0      0          0      0       0      0
# magnolia                0      0      0          0      0       0      0
# wine                    0      0      0          0      0       0      0
#
#                seaweed  earth  bitter almond  ...   cognac  metal  rancid  \
# turpentine           0      0              0  ...        0      0       0
# urine                0      0              0  ...        0      0       0
# thyme                0      0              0  ...        0      0       0
# green tea            0      0              0  ...        0      0       0
# fecal                0      0              0  ...        0      0       0
# fennel               0      0              0  ...        0      0       0
# paper                0      0              0  ...        0      0       0
# seaweed              0      0              0  ...        0      0       0
# earth                0      0              0  ...        0      0       0
# bitter almond        0      0              0  ...        0      0       0
# rubber               0      0              0  ...        0      0       0
# grape                0      0              0  ...        0      0       0
# rose                 0      0              0  ...        0      0       0
# walnut               0      0              0  ...        0      0       0
# celery               0      0              0  ...        0      0       0
# roast beef           0      0              0  ...        0      0       0
# geranium             0      0              0  ...        0      1       0
# wood                 0      1              0  ...        0      0       0
# orange               0      0              0  ...        0      0       0
# sulfur               0      0              0  ...        0      0       0
# spice                0      3              0  ...        0      0       0
# green leaf           0      0              0  ...        0      0       0
# coffee               0      0              0  ...        0      0       0
# yeast                0      0              0  ...        0      0       0
# citrus               0      1              0  ...        0      0       1
# fat                  0      0              0  ...        0      0       3
# mandarin             0      0              0  ...        0      0       0
# watermelon           0      0              0  ...        0      0       0
# nutmeg               0      0              0  ...        0      0       0
# burnt                0      0              0  ...        0      1       0
# ...                ...    ...            ...  ...      ...    ...     ...
# ester                0      0              0  ...        0      0       0
# orris                0      0              0  ...        0      0       0
# lily                 0      0              0  ...        0      0       0
# soap                 0      0              0  ...        0      0       0
# cinnamon             0      0              0  ...        0      0       0
# black currant        0      0              0  ...        0      0       0
# mustard              0      0              0  ...        0      0       0
# pear                 0      0              0  ...        0      0       0
# hawthorne            0      0              0  ...        0      0       0
# orange peel          0      0              0  ...        0      0       0
# fruit                0      0              0  ...        0      0       0
# garlic               0      0              0  ...        0      0       0
# moss                 0      2              0  ...        0      0       0
# dust                 0      0              0  ...        0      0       0
# cabbage              0      0              0  ...        0      0       0
# grapefruit           0      0              0  ...        0      0       0
# broccoli             0      0              0  ...        0      0       0
# tomato               0      0              0  ...        0      0       0
# caraway              0      0              0  ...        0      0       0
# potato               0      0              0  ...        0      0       0
# cognac               0      0              0  ...        0      0       0
# metal                0      0              0  ...        0      0       0
# rancid               0      0              0  ...        0      0       0
# green                1      3              0  ...        0      1       0
# camphor              0      1              0  ...        0      0       0
# pineapple            0      0              0  ...        0      0       0
# fresh                0      0              0  ...        0      0       0
# baked                0      0              0  ...        0      0       0
# magnolia             0      0              0  ...        0      0       0
# wine                 0      0              0  ...        0      0       0
#
#                green  camphor  pineapple  fresh  baked  magnolia  wine
# turpentine         0        0          0      0      0         0     0
# urine              0        0          0      0      0         0     0
# thyme              0        0          0      0      0         0     0
# green tea          0        0          0      0      0         0     0
# fecal              0        0          0      0      0         0     0
# fennel             0        0          0      0      0         0     0
# paper              0        0          0      0      0         0     0
# seaweed            1        0          0      0      0         0     0
# earth              3        1          0      0      0         0     0
# bitter almond      0        0          0      0      0         0     0
# rubber             1        0          0      0      0         0     0
# grape              0        0          0      0      0         0     0
# rose               1        0          0      0      0         0     0
# walnut             1        0          0      0      0         0     0
# celery             0        0          0      0      0         0     0
# roast beef         0        0          0      0      0         0     0
# geranium           0        0          0      0      0         0     0
# wood               5        1          0      0      0         0     0
# orange             1        0          0      1      0         0     0
# sulfur             1        0          0      0      0         0     0
# spice              0        0          0      1      0         0     0
# green leaf         0        0          0      0      0         0     0
# coffee             0        0          0      0      0         0     0
# yeast              0        0          0      0      0         0     0
# citrus             4        1          0      2      0         0     0
# fat                9        0          0      0      0         0     0
# mandarin           0        0          0      0      0         0     0
# watermelon         0        0          0      0      0         0     0
# nutmeg             0        0          0      0      0         0     0
# burnt              0        0          0      0      0         0     0
# ...              ...      ...        ...    ...    ...       ...   ...
# ester              0        0          0      0      0         0     0
# orris              0        0          0      0      0         0     0
# lily               0        0          0      0      0         0     0
# soap               3        0          0      0      0         0     0
# cinnamon           0        0          0      0      0         0     0
# black currant      0        0          0      0      0         0     0
# mustard            0        0          0      0      0         0     0
# pear               0        0          0      0      0         0     0
# hawthorne          0        0          0      0      0         0     0
# orange peel        0        0          0      0      0         0     0
# fruit              4        0          0      1      0         0     2
# garlic             0        0          0      0      0         0     0
# moss               0        0          0      1      0         0     0
# dust               0        0          0      0      0         0     0
# cabbage            0        0          0      0      0         0     0
# grapefruit         0        0          0      0      0         0     0
# broccoli           0        0          0      0      0         0     0
# tomato             0        0          0      0      0         0     0
# caraway            0        0          0      1      0         0     0
# potato             0        0          0      0      0         0     0
# cognac             0        0          0      0      0         0     0
# metal              1        0          0      0      0         0     0
# rancid             0        0          0      0      0         0     0
# green              0        1          0      2      0         1     2
# camphor            1        0          0      0      0         0     0
# pineapple          0        0          0      0      0         0     0
# fresh              2        0          0      0      0         0     0
# baked              0        0          0      0      0         0     0
# magnolia           1        0          0      0      0         0     0
# wine               2        0          0      0      0         0     0
#
# [196 rows x 196 columns]

# %%
edges = 0
nodes = 0
total_weight = 0
avg_weight_per_node = 0

for i in cooc_zero_diagonal.index:
    if cooc_zero_diagonal[i].sum(axis=0) > 0:
        nodes += 1
        for j in cooc_zero_diagonal.columns:
            if cooc_zero_diagonal[i][j] > 0:
                edges += 1
                total_weight += cooc_zero_diagonal[i][j]

#  Average weight = total weight / amount of nodes + 0.00 to convert int to float                
avg_weight_per_node = total_weight/(nodes + 0.00)

avg_degree = (2 * edges) / (nodes + 0.00)

graph_density = avg_degree / (nodes-1)

# %% [markdown]
# ## Using networkX for network analysis and comparrison with Random Networks

# %%
# %matplotlib inline
import networkx as nx

cooc_matrix = cooc_zero_diagonal.values

square_matrix_size = cooc_matrix[0].size

adj_matrix = np.zeros((square_matrix_size, square_matrix_size), dtype=np.int64)
# Out:
# 0

# %%
# Build adjacency Matrix from Cooccurrence Matrix 
for i in range(0, square_matrix_size):
    for j in range(0, square_matrix_size):
        if cooc_matrix[i][j] > 0:
            adj_matrix[i][j] = 1
            
adj_matrix_df = pd.DataFrame(data=adj_matrix, index=cooc_zero_diagonal.index, columns=cooc_zero_diagonal.index, dtype=None, copy=False)
            
adj_matrix_df.index[176]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-17-35321e1a452c> in <module>()
#       1 # Build adjacency Matrix from Cooccurrence Matrix
# ----> 2 for i in range(0, square_matrix_size):
#       3     for j in range(0, square_matrix_size):
#       4         if cooc_matrix[i][j] > 0:
#       5             adj_matrix[i][j] = 1
#
# NameError: name 'square_matrix_size' is not defined

# %%
import matplotlib.pyplot as plt

Adj = nx.from_numpy_matrix(adj_matrix)

print("Nodes: " + len(Adj).__str__())
print("Edges: " + Adj.size().__str__())

nx.draw(Adj)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-16-f56527d9946f> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 Adj = nx.from_numpy_matrix(adj_matrix)
#       4
#       5 print("Nodes: " + len(Adj).__str__())
#
# NameError: name 'nx' is not defined

# %%
avg_clustering_coef = nx.average_clustering(Adj)
avg_clustering_coef
# Out:
# 0.33760226997716725

# %%
# Now we add the weights to the graph and calculate the average weighted clustering coefficient

# Use Cooccurrence Matrix to add weights to adjacency network
# Builds our Cooccurence Network (Weighted Adjacency Network)
for i in range(0, square_matrix_size):
    for j in range(0, square_matrix_size):
        if cooc_matrix[i][j] > 0:
            Adj.edges[i, j]['weight'] = cooc_matrix[i][j]

# %%
Adj.edges(data=True)
# Out:
# EdgeDataView([(0, 130, {'weight': 1}), (0, 37, {'weight': 1}), (0, 71, {'weight': 1}), (0, 162, {'weight': 2}), (0, 47, {'weight': 1}), (0, 176, {'weight': 1}), (0, 17, {'weight': 1}), (0, 20, {'weight': 1}), (0, 153, {'weight': 1}), (0, 28, {'weight': 1}), (2, 17, {'weight': 1}), (2, 66, {'weight': 1}), (3, 65, {'weight': 1}), (3, 20, {'weight': 1}), (4, 116, {'weight': 1}), (4, 109, {'weight': 1}), (5, 153, {'weight': 1}), (5, 115, {'weight': 1}), (7, 59, {'weight': 1}), (7, 148, {'weight': 1}), (7, 78, {'weight': 1}), (7, 54, {'weight': 1}), (7, 189, {'weight': 1}), (8, 65, {'weight': 2}), (8, 130, {'weight': 4}), (8, 67, {'weight': 1}), (8, 70, {'weight': 1}), (8, 38, {'weight': 1}), (8, 113, {'weight': 1}), (8, 17, {'weight': 1}), (8, 178, {'weight': 2}), (8, 20, {'weight': 3}), (8, 190, {'weight': 1}), (8, 150, {'weight': 1}), (8, 24, {'weight': 1}), (8, 189, {'weight': 3}), (8, 126, {'weight': 1}), (10, 96, {'weight': 1}), (10, 160, {'weight': 1}), (10, 71, {'weight': 1}), (10, 109, {'weight': 1}), (10, 47, {'weight': 1}), (10, 121, {'weight': 1}), (10, 189, {'weight': 1}), (11, 103, {'weight': 1}), (12, 96, {'weight': 2}), (12, 65, {'weight': 1}), (12, 131, {'weight': 1}), (12, 176, {'weight': 5}), (12, 45, {'weight': 1}), (12, 125, {'weight': 1}), (12, 16, {'weight': 1}), (12, 189, {'weight': 1}), (12, 179, {'weight': 1}), (12, 20, {'weight': 1}), (12, 149, {'weight': 4}), (12, 93, {'weight': 3}), (13, 189, {'weight': 1}), (13, 21, {'weight': 1}), (13, 59, {'weight': 1}), (13, 60, {'weight': 1}), (13, 125, {'weight': 1}), (13, 126, {'weight': 1}), (13, 31, {'weight': 1}), (14, 176, {'weight': 1}), (14, 59, {'weight': 1}), (14, 76, {'weight': 1}), (15, 66, {'weight': 1}), (15, 84, {'weight': 2}), (15, 98, {'weight': 2}), (16, 136, {'weight': 1}), (16, 187, {'weight': 1}), (17, 65, {'weight': 5}), (17, 91, {'weight': 1}), (17, 71, {'weight': 1}), (17, 96, {'weight': 5}), (17, 106, {'weight': 4}), (17, 66, {'weight': 1}), (17, 189, {'weight': 5}), (17, 176, {'weight': 1}), (17, 114, {'weight': 1}), (17, 20, {'weight': 9}), (17, 53, {'weight': 1}), (17, 54, {'weight': 1}), (17, 151, {'weight': 1}), (17, 24, {'weight': 2}), (17, 59, {'weight': 3}), (17, 125, {'weight': 1}), (17, 190, {'weight': 1}), (18, 192, {'weight': 1}), (18, 189, {'weight': 1}), (18, 53, {'weight': 1}), (18, 157, {'weight': 1}), (19, 35, {'weight': 1}), (19, 36, {'weight': 1}), (19, 177, {'weight': 4}), (19, 40, {'weight': 2}), (19, 47, {'weight': 2}), (19, 48, {'weight': 1}), (19, 136, {'weight': 2}), (19, 180, {'weight': 3}), (19, 189, {'weight': 1}), (19, 29, {'weight': 1}), (19, 126, {'weight': 1}), (20, 130, {'weight': 1}), (20, 146, {'weight': 1}), (20, 149, {'weight': 1}), (20, 25, {'weight': 1}), (20, 152, {'weight': 1}), (20, 153, {'weight': 2}), (20, 156, {'weight': 2}), (20, 164, {'weight': 1}), (20, 38, {'weight': 1}), (20, 45, {'weight': 1}), (20, 176, {'weight': 1}), (20, 178, {'weight': 1}), (20, 59, {'weight': 4}), (20, 192, {'weight': 1}), (20, 65, {'weight': 5}), (20, 71, {'weight': 1}), (20, 96, {'weight': 2}), (20, 97, {'weight': 1}), (20, 104, {'weight': 1}), (20, 106, {'weight': 2}), (20, 125, {'weight': 2}), (22, 40, {'weight': 1}), (23, 176, {'weight': 1}), (24, 130, {'weight': 1}), (24, 144, {'weight': 2}), (24, 25, {'weight': 3}), (24, 153, {'weight': 1}), (24, 32, {'weight': 1}), (24, 162, {'weight': 2}), (24, 168, {'weight': 1}), (24, 47, {'weight': 1}), (24, 176, {'weight': 1}), (24, 50, {'weight': 1}), (24, 51, {'weight': 2}), (24, 59, {'weight': 1}), (24, 188, {'weight': 1}), (24, 189, {'weight': 4}), (24, 190, {'weight': 1}), (24, 192, {'weight': 2}), (24, 65, {'weight': 1}), (24, 72, {'weight': 1}), (24, 93, {'weight': 1}), (24, 96, {'weight': 2}), (25, 130, {'weight': 1}), (25, 141, {'weight': 1}), (25, 146, {'weight': 1}), (25, 148, {'weight': 2}), (25, 155, {'weight': 1}), (25, 157, {'weight': 1}), (25, 159, {'weight': 1}), (25, 167, {'weight': 1}), (25, 168, {'weight': 1}), (25, 41, {'weight': 2}), (25, 46, {'weigh ...

# %%
avg_weighted_clustering_coef = nx.average_clustering(Adj, weight='weight')
avg_weighted_clustering_coef
# Out:
# 0.030541248072555895

# %%
# Build Random Networks for comparison using Erdos Renyi (n, M) model

import operator as op
def ncr(n, r):
    r = min(r, n-r)
    numer = reduce(op.mul, xrange(n, n-r, -1), 1)
    denom = reduce(op.mul, xrange(1, r+1), 1)
    return numer//denom

p = Adj.size()/float(ncr(len(Adj), 2))  

random_graphs = []

for i in range(0,999):
    random_graphs.append(nx.erdos_renyi_graph(len(Adj), p))

# %%
random_clustering_coeffs = []

for graph in random_graphs:
    random_clustering_coeffs.append(nx.average_clustering(graph))

# %%
from statsmodels.stats import weightstats as stests

z_score, p_val = stests.ztest(random_clustering_coeffs, value = avg_clustering_coef)

random_graph_mean_CC = sum(random_clustering_coeffs) / len(random_clustering_coeffs)

# %%
print('Flavornet Network\n')

print("Total Smells in Dataset:" + len(cooc_zero_diagonal.index).__str__() + "\n")
print('Total Edges: ' + edges.__str__())
print('Total Nodes: ' + nodes.__str__())
print('Total Weight: ' + total_weight.__str__())
print('Average Weight (per node): ' + avg_weight_per_node.__str__() + '\n')
print('Average Degree: ' + avg_degree.__str__())
print('Graph Density: ' + graph_density.__str__())
print('Average Clustering Coefficient: ' + avg_clustering_coef.__str__())
print('Average Weighted Clustering Coefficient: (Onnela et al) ' + avg_weighted_clustering_coef.__str__() + "\n")

print("Average Clustering Coefficient of Random Graphs:" + random_graph_mean_CC.__str__())
print("Z-score for comparing real network with random distribution: " + z_score.__str__())
print("p-value for Z-test (too small to display): " + p_val.__str__())
# Out:
# Flavornet Network
#
# Total Smells in Dataset:196
#
# Total Edges: 930
# Total Nodes: 171
# Total Weight: 1354
# Average Weight (per node): 7.918128654970761
#
# Average Degree: 10.8771929825
# Graph Density: 0.0639834881321
# Average Clustering Coefficient: 0.337602269977
# Average Weighted Clustering Coefficient: (Onnela et al) 0.030541248072555895
#
# Average Clustering Coefficient of Random Graphs:0.0230816313158
# Z-score for comparing real network with random distribution: -1431.6266150633473
# p-value for Z-test (too small to display): 0.0

# %% [markdown]
# ## Results
#
# Our results closely match those of the PLOS one paper from 2015. These results help us to establish that:
#
# - A) Our data collection and coocurrence network were completed succesfully, helping to verify previous work and our own dataset
# - B) The data collected is signifficanly different to a random network
#
# Our Average Clustering Coefficient was 0.3376... compared to 0.34 from the previous research.
#
# Our Average Clustering Coefficient for Random Graphs was 0.02308... compared to 0.0223 reported in the previous experiments.
#
# The z-test tells us that our real network's value for the average clustering coefficient is 1431 standard deviations away from the mean of the normally distributed values for the corresponding random graphs. The probability that our real network comes from this distribution is too small to display (due to the limits of floating point numbers) i.e. diplayed as 0.0
#
# The slight differences in the number of nodes/edges collected (2015 vs present) and the random nature of the graph generation explain the small variation in our results.
