# %%
# %matplotlib inline

import scipy
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
import json
import numpy as np
import pandas as pd
import xlrd

# %%
keller_data = pd.read_excel('/Users/admin/workspace/2018-mcm-kealyd2/data/KellerData.xlsx', header=1, skiprows=1)

# %%
perceptual_descriptors = keller_data.iloc[:, 18:38]
perceptual_descriptors.insert(0, 'CAS', keller_data.iloc[:, 0])

# %%
perceptual_descriptors
# Out:
#               CAS  EDIBLE   BAKERY   SWEET   FRUIT   FISH  GARLIC   SPICES   \
# 0       2257-09-2      NaN      NaN    16.0     NaN   NaN      NaN      NaN
# 1       2257-09-2      NaN      NaN    57.0     NaN   NaN      NaN      NaN
# 2       2442-10-6      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 3       2442-10-6      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 4       2530-10-1      NaN      NaN     NaN     NaN   NaN      NaN      7.0
# 5       2530-10-1      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 6       4075-07-4      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 7       4075-07-4      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 8       5461-08-5      NaN      NaN     NaN     NaN   NaN      NaN      NaN
# 9       5461-08-5      NaN      NaN     NaN     NaN   NaN      NaN      7.0
# 10      7554-12-3      NaN      NaN     NaN     NaN  55.0      NaN      NaN
# ...

# %%
physical_descriptors = pd.read_table

# %% [markdown]
# # Receptor Response levels & Physical/Phenomenilogical  data for 64 odorants
#
# I have found a dataset which measures OR reactions to 64 odorants contained within out preceptual-physical descriptors dataset (Keller '14/'17).
#
# This crossover of datasets gives us the entire picture of structure-odor relationship including a detailed representation of each major stage of the olfactory processing. From 5000 molecular features (chemical space) to 511 responses to cloned human olfactory receptors (neural space) and finally the preceptual qualities as rated by 49 individuals acccounting for both indivualised and population level final concious perception.
#
# The limiting factor seems to be that we only have the full chain of data for these 64 molecules and some of these molecules did not register any significant responses in the ORs tested. The lack of significant response also contains information in my estimation so these data points will still be useful. It may be possible to find more data or to do something useful with this overlap.
#
# Perhaps because we only have 64 molecules this information could be best used to investigate the within population variablity. Perhaps looking at the molecules for which we have OR maps AND preceptual/physical descriptors we can study whether there are any correlations between receptor type and physcial descriptors of it's ligand and we can also check the correlations between receptor-ligand pairings and the perceptual descriptors associated with the ligand in question.

# %%
# This is a new dataset containing odorant responses to 511 cloned human olfactory receptors
# Responses are measured in a cAMP measure that corelates with OR activation level 
# cAMP is the chemical which drives G-Protein-Coupled-Receptors activation through ligand interaction
# Human olfactory receptros are a subset  of these (GPCRs) - 1991 research & 2004 Nobel Prize
OR_response_mols = pd.read_table("/Users/admin/Google Drive/College/Masters - MCM/CA685 - Practicum/Data Sets/OR Responses 71 Mols/Odors.tsv")
OR_response_mols = pd.read_table("/Users/admin/Google Drive/College/Masters - MCM/CA685 - Practicum/Data Sets/OR Responses 71 Mols/.tsv")

# %%
# Here I am checking to see how many of these molecules are in my Keller dataset
crossover = 0 
total_odor_OR_maps = 0

for cas in OR_response_mols['CASRegistryNum']:  
    total_odor_OR_maps +=1
    if isinstance(cas, float):
        cas = str(cas)
    ucas = unicode(cas, "ascii")
    for keller_cas in perceptual_descriptors['CAS']:
        if keller_cas == ucas: # If we find a match, count and break the loop
            crossover += 1
            break
        
print("Crossover Mols: " + crossover.__str__())
print("Total Mols Available: " + total_odor_OR_maps.__str__())
# Out:
# Crossover Mols: 64
# Total Mols Available: 116

# %% [markdown]
# # Conclusion
# ---
# This avenue was not followed up on as it fell outside the final scope of the investigation.
